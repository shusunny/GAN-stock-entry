# %% [markdown]
# # Imports

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# general array and data handling
import numpy as np
import pandas as pd

# tensor operations and neural networks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LeakyReLU, Flatten

# Ploting
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Loading

# %%
#for use in google colaboratory
#!git clone https://github.com/shusunny/GAN-stock-entry.git

# %%
data_names = ["GOOG","AAPL","AMZN","FB","TSLA"]
data_name = data_names[0]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path)
# Out:
# GAN-stock-entry/datasets/GOOG.csv

# %%
dataframe.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   1089.420897  1100.046811  1079.321435  1090.083688  1090.083688
# std     268.589405   272.693779   265.381490   269.099996   269.099996
# min     667.849976   672.299988   663.059998   668.260010   668.260010
# 25%     835.755005   841.975006   831.254975   836.994995   836.994995
# 50%    1083.560059  1094.244995  1072.204956  1082.760010  1082.760010
# 75%    1229.390015  1241.369995  1219.445007  1230.540039  1230.540039
# max    1824.520020  1847.199951  1822.650024  1827.989990  1827.989990
#
#              Volume
# count  1.259000e+03
# mean   1.671534e+06
# std    7.686312e+05
# min    3.468000e+05
# 25%    1.209400e+06
# 50%    1.466700e+06
# 75%    1.889050e+06
# max    6.348100e+06

# %%
dataframe.shape
# Out:
# (1259, 7)

# %%
def add_Entry(dataframe):
  for i in range(0,dataframe.shape[0]):
    dataframe.loc[dataframe.index[i],'Entry'] = np.round((dataframe.iloc[i,3]+ (dataframe.iloc[i,2] -dataframe.iloc[i,3])*0.2),5)
  return dataframe

dataframe=add_Entry(dataframe)
dataframe.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-01-04  743.000000  744.059998  731.257996  741.840027  741.840027
# 1  2016-01-05  746.450012  752.000000  738.640015  742.580017  742.580017
# 2  2016-01-06  730.000000  747.179993  728.919983  743.619995  743.619995
# 3  2016-01-07  730.309998  738.500000  719.059998  726.390015  726.390015
# 4  2016-01-08  731.450012  733.229980  713.000000  714.469971  714.469971
#
#     Volume      Entry
# 0  3272800  733.81840
# 1  1950700  741.31201
# 2  1947000  732.57198
# 3  2963700  722.94800
# 4  2450900  717.04600

# %%
ax = plt.gca()
dataframe.iloc[0:100].plot(x='Date',y='Open',ax=ax)
dataframe.iloc[0:100].plot(x='Date',y='Entry', ax=ax)

plt.title("First 100 days Open and Entry price")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# # Preprocessing

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    # shape : (n_batch, n_sequence, n_features)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    std[std==0] = 1
    samples = (samples - mean[:,None,:])/std[:,None,:] #standarize along each feature
    targets = (targets - mean[:,6:7])/std[:,6:7] # The entry value is our target
    return samples, targets

# %%
# TimeseriesGenerator Check

data = np.array([[i, i**2,i**3,i**4] for i in range(11)])
targets = np.array([[i**4] for i in range(11)])

print(targets.shape)

mean = data[:-1].mean(axis=0)[None,:]
std = data[:-1].std(axis=0)[None,:]

data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=10, sampling_rate=1,
                               batch_size=2)
batch_0 = data_gen[0]
x, y = batch_0

print(np.array(x*std+mean,dtype = np.int))
print(y*std[..., 3]+mean[..., 3])
# Out:
# (11, 1)
# [[[   0    0    0    0]
#   [   1    1    1    1]
#   [   2    4    8   16]
#   [   3    9   27   81]
#   [   4   16   64  256]
#   [   5   25  125  625]
#   [   6   36  216 1296]
#   [   7   49  343 2401]
#   [   8   64  512 4096]
#   [   9   81  729 6561]]]
# []

# %%
data.shape
# Out:
# (11, 4)

# %%
n_sequence = 5
n_batch = 128
n_features = 7

def get_gen_train_test(dataframe):
  data = dataframe.drop(columns='Date').to_numpy()
  targets = data[:,3, None] #add none to have same number of dimensions as data
  #targets = data
  n_samples = data.shape[0]

  train_test_split=int(n_samples*0.9)

  data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
  data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)
  
  return data_gen_train, data_gen_test

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

# %%
data_gen_train[0]
# Out:
# (array([[[-1.00320052, -0.60796735, -0.52852512, ..., -0.51446086,
#            0.15124694, -0.56184467],
#          [ 0.1233268 ,  1.00062145,  1.70094551, ...,  1.88730777,
#            0.58120589,  1.58708667],
#          [ 1.70283029,  1.32972209,  0.562825  , ...,  0.04391792,
#            1.46940101,  0.75609494],
#          [ 0.19684706, -0.42662987, -0.91829469, ..., -0.41867626,
#           -0.93343869, -0.83055914],
#          [-1.01980364, -1.29574632, -0.8169507 , ..., -0.99808857,
#           -1.26841514, -0.9507778 ]],
#
#         [[-1.80999491, -1.86821153, -1.89244304, ..., -1.31015452,
#           -0.48733988, -1.93972758],
#          [-0.1365191 ,  0.37033714,  0.91193232, ...,  1.32937964,
#            1.70252606,  0.8223663 ],
#          [ 1.11858284,  1.04809473, -0.02711779, ..., -0.27465898,
#            0.54022161,  0.20009542],
#          [ 0.17804358, -0.06920426,  0.30551423, ...,  0.96681887,
#           -1.00287815,  0.23453021],
#          [ 0.64988759,  0.51898391,  0.70211429, ..., -0.71138501,
#           -0.75252964,  0.68273566]],
#
#         [[-1.81982606, -1.6192523 , -1.79433394, ..., -1.49456553,
#            0.00316772, -1.78181522],
#          [-0.26703386, -0.54007415, -0.25920444, ..., -0.08426464,
#           -1.78355089, -0.29750091],
#          [ 0.46927513,  0.35316097,  0.23321808, ..., -0.60437852,
#            1.16852494,  0.25028343],
#          [ 0.59853466,  1.30959373,  0.87849687, ...,  1.16474751,
#           -0.05896842,  0.94006645],
#          [ 1.01905013,  0.49657175,  0.94182343, ...,  1.01846118,
#            0.67082664,  0.88896625]],
#
#         ...,
#
#         [[-1.35521461, -1.90598032, -1.31254783, ..., -1.98768388,
#           -0.54628324, -1.43895321],
#          [-0.87029266,  0.04615295, -0.77114769, ...,  0.51482651,
#            1.53012346, -0.65029618],
#          [ 0.03279953,  0.25443115, -0.1831265 , ...,  0.68973492,
#            0.83135824, -0.11368386],
#          [ 1.07485223,  0.8792657 ,  1.33312714, ...,  0.4206458 ,
#           -1.01168475,  1.28469746],
#          [ 1.11785551,  0.72613052,  0.93369489, ...,  0.36247663,
#           -0.8035137 ,  0.91823578]],
#
#         [[-1.53210258, -1.5042114 , -1.51375692, ..., -0.23393884,
#            1.53249586, -1.5142612 ],
#          [-0.32281836, -0.84630622, -0.7425563 , ...,  0.89488471,
#            0.84636975, -0.75097492],
#          [ 1.07254069,  1.12740918,  1.24603826, ..., -0.84176214,
#           -0.96333668,  1.23810591],
#          [ 1.13012417,  0.64368871,  0.72217551, ..., -1.21717421,
#           -0.75893099,  0.71684472],
#          [-0.34774392,  0.57941974,  0.28809945, ...,  1.39799049,
#           -0.65659795,  0.31028549]],
#
#         [[ 1.11914988,  0.73011403,  1.02110425, ..., -0.23033719,
#            1.95140643,  0.95481055],
#          [ 0.06933221, -0.02180926,  0.03790512, ..., -0.36678855,
#           -0.34705112,  0.01849707],
#          [-0.96504888, -1.88989286, -1.43491768, ..., -1.32738926,
#           -0.85326184, -1.64109327],
#          [-1.29205894,  0.27719588, -0.76762605, ...,  1.73639241,
#           -0.55082078, -0.43156086],
#          [ 1.06862573,  0.90439221,  1.14353435, ...,  0.18812259,
#           -0.20027269,  1.09934651]]]),
#  array([[ 1.28187441],
#         [ 5.20395537],
#         [ 1.57572929],
#         [ 2.79422321],
#         [ 1.34372831],
#         [ 1.10269052],
#         [ 0.34118691],
#         [-0.89285368],
#         [ 0.52048424],
#         [ 2.05398928],
#         [ 2.59224633],
#         [ 5.04857484],
#         [ 1.76812211],
#         [ 0.87820907],
#         [ 2.36373387],
#         [ 6.4920553 ],
#         [ 0.49954838],
#         [ 2.34192447],
#         [ 2.76783842],
#         [-5.33570598],
#         [ 3.86609401],
#         [-3.15390619],
#         [ 2.68750809],
#         [-0.64252287],
#         [-5.24222459],
#         [ 7.43267244],
#         [ 1.85601747],
#         [ 9.71271698],
#         [-1.04706107],
#         [ 2.03419307],
#         [-1.9152474 ],
#         [ 1.62079708],
#         [ 1.68570523],
#         [-0.17528483],
#         [ 1.4822308 ],
#         [-0.35257455],
#         [-1.33369649],
#         [ 1.24973314],
#         [-4.35238177],
#         [-1.68706153],
#         [ 0.07072294],
#         [-0.10288744],
#         [ 3.62790246],
#         [ 0.50919546],
#         [ 0.09924307],
#         [ 2.09133899],
#         [-0.5318048 ],
#         [-0.49659984],
#         [ 1.73305898],
#         [-0.69197025],
#         [-2.48603858],
#         [ 1.68570523],
#         [ 1.98009466],
#         [-0.11663037],
#         [ 2.9575662 ],
#         [ 2.26325556],
#         [ 1.11238974],
#         [ 6.91087192],
#         [ 9.37108182],
#         [ 2.99774741],
#         [ 7.06764958],
#         [-1.30839931],
#         [ 0.45635716],
#         [ 0.09924307],
#         [ 2.0298563 ],
#         [-0.38920668],
#         [-0.16355058],
#         [ 8.18872265],
#         [-0.1899928 ],
#         [ 1.27677316],
#         [-0.86871908],
#         [ 2.91484484],
#         [ 0.8638729 ],
#         [ 5.86887253],
#         [ 1.87460616],
#         [ 1.56722898],
#         [-2.81468897],
#         [ 1.95738782],
#         [ 1.44422905],
#         [ 0.64157649],
#         [ 2.25046844],
#         [ 3.36092872],
#         [-1.86477145],
#         [ 0.52574494],
#         [ 5.0094631 ],
#         [ 1.31624388],
#         [ 1.85749933],
#         [ 3.48871651],
#         [ 1.12230336],
#         [ 3.85910257],
#         [ 0.54979303],
#         [ 0.86792565],
#         [ 0.74193105],
#         [ 0.02257538],
#         [ 1.18109577],
#         [ 3.40898905],
#         [ 4.2278979 ],
#         [ 2.03419307],
#         [-7.12210108],
#         [ 1.34372831],
#         [ 1.6009198 ],
#         [ 0.71263704],
#         [-1.78659139],
#         [-6.55027943],
#         [-0.71016512],
#         [-1.07546002],
#         [ 3.96811767],
#         [-5.33570598],
#         [ 1.02735965],
#         [ 1.56374844],
#         [ 7.13864333],
#         [-0.47326891],
#         [ 1.42140553],
#         [ 2.28696485],
#         [ 1.57572929],
#         [ 2.0298563 ],
#         [ 2.60326057],
#         [ 2.90472554],
#         [ 0.3764811 ],
#         [ 1.74184335],
#         [ 0.73727909],
#         [ 3.41025238],
#         [ 2.24323058],
#         [ 1.03487474],
#         [ 1.53721836],
#         [ 1.6546538 ],
#         [-0.13399912],
#         [-4.40120766]]))

# %%
# test on data

x_gen, y_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=1)[0]
print(x_gen)
print(y_gen)

x = data[None, :5,:]
mean = x.mean(axis=1)
std = x.std(axis=1)
x = (x - mean)/std
y = (data[5,3] - mean[...,3])/std[...,3]
print(x)
print(y)

assert (x_gen == x).all()
assert (y_gen == y).all()
# Out:
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# []
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [5.69853465]

# %%
y_gen.shape
# Out:
# (1, 0)

# %% [markdown]
# # Baseline

# %%
# baseline: use previous day as estimation for the next
squared_error = 0
def mean_squared_error(X, lenght = 5):
  squared_error = 0
  for i in range(0, X.shape[0] - lenght):
    x = X[i:i+lenght]
    mean = x.mean()
    std = x.std()
    x = (x - mean)/std
    y = (X[i+lenght] - mean)/std
    squared_error += np.square(x[-1]-y)
  return squared_error/X.shape[0]

baseline_error = mean_squared_error(data[:,3])
baseline_error
# Out:
# 3.4528189810500125

# %%
data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=32)

# baseline: use previous day as estimation for the next
def mean_squared_error(dataset):
  mse=0
  for X_batch, y_batch in dataset:
    # X_batch.shape : (n_batch, n_sequence, n_features)
    #mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
    mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
  mse /= len(dataset)
  return mse

baseline_error = mean_squared_error(data_gen)
baseline_error
# Out:
# C:\Users\shusu\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\shusu\Anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %% [markdown]
# # Utilities

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
def mse(y_true, y_pred):
  return tf.reduce_mean(tf.square(y_true-y_pred))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true-y_pred)))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:] > y_true[:-1],tf.float32)
    return tf.reduce_mean((y_true[1:]-y_true[:-1])*mask)

# %% [markdown]
# # ANN

# %%
def make_ANN_model():

  inputs = Input(shape=(n_sequence, n_features,))
  inputs_flatten = Flatten()(inputs)
  ann_1 = Dense(units=1000, activation=None)(inputs_flatten)
  batch_norm1=tf.keras.layers.BatchNormalization()(ann_1)
  ann_1_LRelu = LeakyReLU(alpha=0.3)(ann_1) 
  ann_1_droput = Dropout(0.3)(ann_1_LRelu)
  ann_2 = Dense(units=100, activation=None)(ann_1_droput)
  batch_norm2=tf.keras.layers.BatchNormalization()(ann_2)
  ann_2_LRelu = LeakyReLU(alpha=0.3)(ann_2) 
  ann_2_droput = Dropout(0.3)(ann_2_LRelu)
  output_dense = Dense(1, activation=None)(ann_2_droput)
  output = LeakyReLU(alpha=0.3)(output_dense) 


  model = Model(inputs = inputs, outputs = output)
  #model.compile(loss=generator_loss)
  model.compile(loss='mse', metrics = [mse , mae, mape, rmse, ar])
  #model.compile(loss=None, metrics = [mse , mae, mape, rmse])
  model.summary()

  #return model, slice_model
  return model

# %% [markdown]
# # Visualization

# %%
metrics = ["loss", 'mse','mae','mape','rmse','ar']
def plot_history(history):
  #metrics = ["loss", 'mse','mae','mape','rmse','ar']
  #metrics = ["gen_loss","gen_slice_loss", 'mse','mae','mape','rmae','ar']
  for metric_name in metrics:  
    plt.figure()
    plt.title(metric_name)
    plt.xlabel('Iterations')
    plt.ylabel(metric_name)
    plt.plot(history.history[metric_name], label='train')
    plt.plot(history.history["val_"+metric_name], label='test')
    plt.legend()
  plt.show()

#plot_history(history)

# %%
def plot_frame(sequence, target, model):
  sequence, target = data_gen_test[0]
  y_pred = model.predict(sequence)
  y_true = target

  plt.figure()
  plt.title("Entry price errors")
  plt.xlabel('Test samples')
  plt.ylabel("Errors")
  plt.plot(y_true, label="true")
  plt.plot(y_pred, label="prediction")
  plt.legend()
  plt.show()

#plot_frame(*data_gen_test[0], lstm)

# %% [markdown]
# # Test on all datasets

# %%
results = np.zeros((5,6))

# %% [markdown]
# ### Google Stock

# %%
data_name = data_names[0]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100,
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[0] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/GOOG.csv
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten (Flatten)            (None, 35)                0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1000)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 29ms/step - loss: 7.3094 - mse: 7.3094 - mae: 1.7243 - mape: 2.0179 - rmse: 2.6622 - ar: 1.1079 - val_loss: 4.0769 - val_mse: 4.0769 - val_mae: 1.4963 - val_mape: 3.7198 - val_rmse: 2.0191 - val_ar: 0.5440
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 9.0161 - mse: 9.0161 - mae: 1.6956 - mape: 2.0724 - rmse: 2.9213 - ar: 1.2726 - val_loss: 4.0474 - val_mse: 4.0474 - val_mae: 1.4465 - val_mape: 2.6719 - val_rmse: 2.0118 - val_ar: 0.4452
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.9825 - mse: 5.9825 - mae: 1.5005 - mape: 1.8337 - rmse: 2.3899 - ar: 1.1708 - val_loss: 3.9226 - val_mse: 3.9226 - val_mae: 1.4289 - val_mape: 2.7740 - val_rmse: 1.9806 - val_ar: 0.5521
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.1920 - mse: 5.1920 - mae: 1.4526 - mape: 2.0519 - rmse: 2.2471 - ar: 1.1386 - val_loss: 3.9722 - val_mse: 3.9722 - val_mae: 1.4717 - val_mape: 3.4402 - val_rmse: 1.9930 - val_ar: 0.4960
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4015 - mse: 6.4015 - mae: 1.5299 - mape: 2.0682 - rmse: 2.4404 - ar: 1.2159 - val_loss: 4.3111 - val_mse: 4.3111 - val_mae: 1.5516 - val_mape: 4.9324 - val_rmse: 2.0763 - val_ar: 0.4070
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9044 - mse: 4.9044 - mae: 1.4024 - mape: 1.9168 - rmse: 2.1647 - ar: 1.2154 - val_loss: 6.9488 - val_mse: 6.9488 - val_mae: 1.4750 - val_mape: 10.7889 - val_rmse: 2.6360 - val_ar: 0.7172
# Epoch 14/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.4167 - mse: 3.4167 - mae: 1.2921 - mape: 1.7098 - rmse: 1.8353 - ar: 1.1107 - val_loss: 7.0780 - val_mse: 7.0780 - val_mae: 1.4864 - val_mape: 8.8746 - val_rmse: 2.6604 - val_ar: 0.6630
# Epoch 15/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9264 - mse: 3.9264 - mae: 1.3269 - mape: 1.5047 - rmse: 1.9542 - ar: 1.1241 - val_loss: 7.3804 - val_mse: 7.3804 - val_mae: 1.5231 - val_mape: 10.0135 - val_rmse: 2.7167 - val_ar: 0.6735
# Epoch 16/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.3487 - mse: 4.3487 - mae: 1.3796 - mape: 2.0195 - rmse: 2.0494 - ar: 1.1231 - val_loss: 7.4848 - val_mse: 7.4848 - val_mae: 1.6081 - val_mape: 8.1815 - val_rmse: 2.7358 - val_ar: 0.6593
# Epoch 17/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9612 - mse: 3.9612 - mae: 1.3339 - mape: 3.1051 - rmse: 1.9569 - ar: 1.1697 - val_loss: 7.1939 - val_mse: 7.1939 - val_mae: 1.4977 - val_mape: 10.6536 - val_rmse: 2.6821 - val_ar: 0.7118
# [MSE Baseline] train: 4.29063152508862  test: 9.576144001393745
# 1/1 [==============================] - 0s 0s/step - loss: 7.1939 - mse: 7.1939 - mae: 1.4977 - mape: 10.6536 - rmse: 2.6821 - ar: 0.7118

# %% [markdown]
# ### Facebook Stock

# %%
data_name = data_names[3]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[3] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/FB.csv
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 100)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 20ms/step - loss: 6.5407 - mse: 6.5407 - mae: 1.7038 - mape: 2.9183 - rmse: 2.5260 - ar: 1.0528 - val_loss: 8.1644 - val_mse: 8.1644 - val_mae: 1.6823 - val_mape: 1.7377 - val_rmse: 2.8573 - val_ar: 0.8598
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 7.3352 - mse: 7.3352 - mae: 1.5467 - mape: 1.7319 - rmse: 2.6859 - ar: 1.2125 - val_loss: 8.4044 - val_mse: 8.4044 - val_mae: 1.6990 - val_mape: 2.0327 - val_rmse: 2.8990 - val_ar: 0.6226
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.8794 - mse: 5.8794 - mae: 1.5844 - mape: 2.1286 - rmse: 2.4072 - ar: 1.1789 - val_loss: 8.1836 - val_mse: 8.1836 - val_mae: 1.7055 - val_mape: 1.7043 - val_rmse: 2.8607 - val_ar: 0.5581
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1912 - mse: 4.1912 - mae: 1.3498 - mape: 2.1105 - rmse: 2.0392 - ar: 1.0707 - val_loss: 8.3349 - val_mse: 8.3349 - val_mae: 1.6777 - val_mape: 1.8410 - val_rmse: 2.8870 - val_ar: 0.6449
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 6.8099 - mse: 6.8099 - mae: 1.5400 - mape: 1.5904 - rmse: 2.5853 - ar: 1.1664 - val_loss: 8.3838 - val_mse: 8.3838 - val_mae: 1.6985 - val_mape: 1.6597 - val_rmse: 2.8955 - val_ar: 0.5969
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8760 - mse: 4.8760 - mae: 1.4133 - mape: 2.4470 - rmse: 2.1667 - ar: 1.0425 - val_loss: 8.7195 - val_mse: 8.7195 - val_mae: 1.6877 - val_mape: 2.1525 - val_rmse: 2.9529 - val_ar: 0.5832
# [MSE Baseline] train: 6.4212222524313045  test: 9.572238032577555
# 1/1 [==============================] - 0s 1ms/step - loss: 8.7195 - mse: 8.7195 - mae: 1.6877 - mape: 2.1525 - rmse: 2.9529 - ar: 0.5832

# %% [markdown]
# ### Tesla Stock

# %%
data_name = data_names[4]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[4] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/TSLA.csv
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 100)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 22ms/step - loss: 5.6842 - mse: 5.6842 - mae: 1.6330 - mape: 6.9247 - rmse: 2.3423 - ar: 1.1145 - val_loss: 3.2549 - val_mse: 3.2549 - val_mae: 1.2817 - val_mape: 1.1292 - val_rmse: 1.8041 - val_ar: 0.3199
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.0593 - mse: 5.0593 - mae: 1.4948 - mape: 3.8644 - rmse: 2.1982 - ar: 1.1394 - val_loss: 3.2944 - val_mse: 3.2944 - val_mae: 1.3040 - val_mape: 1.0995 - val_rmse: 1.8151 - val_ar: 0.3293
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.8067 - mse: 5.8067 - mae: 1.5419 - mape: 3.5998 - rmse: 2.3883 - ar: 1.1539 - val_loss: 3.4422 - val_mse: 3.4422 - val_mae: 1.3420 - val_mape: 1.2198 - val_rmse: 1.8553 - val_ar: 0.3652
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6795 - mse: 4.6795 - mae: 1.4469 - mape: 2.8710 - rmse: 2.1553 - ar: 1.1763 - val_loss: 3.4541 - val_mse: 3.4541 - val_mae: 1.3544 - val_mape: 1.1885 - val_rmse: 1.8585 - val_ar: 0.3907
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1164 - mse: 4.1164 - mae: 1.4024 - mape: 3.8581 - rmse: 2.0244 - ar: 1.1809 - val_loss: 3.2507 - val_mse: 3.2507 - val_mae: 1.2939 - val_mape: 1.1408 - val_rmse: 1.8030 - val_ar: 0.3281
# Epoch 6/100
# 9/9 [==============================] - 0s 4ms/step - loss: 5.0594 - mse: 5.0594 - mae: 1.5089 - mape: 3.5827 - rmse: 2.2421 - ar: 1.2506 - val_loss: 3.2775 - val_mse: 3.2775 - val_mae: 1.3135 - val_mape: 1.1396 - val_rmse: 1.8104 - val_ar: 0.3081
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1838 - mse: 4.1838 - mae: 1.3771 - mape: 5.1858 - rmse: 2.0406 - ar: 1.1800 - val_loss: 3.2775 - val_mse: 3.2775 - val_mae: 1.2995 - val_mape: 1.0904 - val_rmse: 1.8104 - val_ar: 0.3124
# Epoch 8/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.1697 - mse: 5.1697 - mae: 1.5314 - mape: 1.8264 - rmse: 2.2496 - ar: 1.3059 - val_loss: 3.3829 - val_mse: 3.3829 - val_mae: 1.3523 - val_mape: 1.3369 - val_rmse: 1.8393 - val_ar: 0.3630
# Epoch 9/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.4626 - mse: 4.4626 - mae: 1.4032 - mape: 2.5100 - rmse: 2.0975 - ar: 1.2214 - val_loss: 3.3725 - val_mse: 3.3725 - val_mae: 1.3528 - val_mape: 1.3436 - val_rmse: 1.8364 - val_ar: 0.3496
# Epoch 10/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8026 - mse: 4.8026 - mae: 1.4539 - mape: 2.1329 - rmse: 2.1796 - ar: 1.2086 - val_loss: 3.2293 - val_mse: 3.2293 - val_mae: 1.2919 - val_mape: 1.2662 - val_rmse: 1.7970 - val_ar: 0.3399
# Epoch 11/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1768 - mse: 4.1768 - mae: 1.3934 - mape: 3.8240 - rmse: 2.0312 - ar: 1.2379 - val_loss: 3.4034 - val_mse: 3.4034 - val_mae: 1.3579 - val_mape: 1.3128 - val_rmse: 1.8448 - val_ar: 0.3502
# Epoch 12/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6686 - mse: 4.6686 - mae: 1.4606 - mape: 4.1680 - rmse: 2.1427 - ar: 1.1218 - val_loss: 3.2498 - val_mse: 3.2498 - val_mae: 1.3065 - val_mape: 1.2909 - val_rmse: 1.8027 - val_ar: 0.3166
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.1769 - mse: 4.1769 - mae: 1.3715 - mape: 2.6039 - rmse: 2.0094 - ar: 1.2160 - val_loss: 3.2234 - val_mse: 3.2234 - val_mae: 1.3042 - val_mape: 1.2508 - val_rmse: 1.7954 - val_ar: 0.3445
# Epoch 14/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.3336 - mse: 4.3336 - mae: 1.4005 - mape: 3.8159 - rmse: 2.0702 - ar: 1.2447 - val_loss: 3.1618 - val_mse: 3.1618 - val_mae: 1.3150 - val_mape: 1.1102 - val_rmse: 1.7781 - val_ar: 0.3591
# Epoch 15/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.5035 - mse: 3.5035 - mae: 1.3145 - mape: 5.2303 - rmse: 1.8567 - ar: 1.2041 - val_loss: 3.2271 - val_mse: 3.2271 - val_mae: 1.3253 - val_mape: 1.3889 - val_rmse: 1.7964 - val_ar: 0.2183
# Epoch 16/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.6298 - mse: 3.6298 - mae: 1.3430 - mape: 1.7588 - rmse: 1.8955 - ar: 1.2481 - val_loss: 3.6152 - val_mse: 3.6152 - val_mae: 1.4189 - val_mape: 1.5175 - val_rmse: 1.9014 - val_ar: 0.2157
# Epoch 17/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.2425 - mse: 4.2425 - mae: 1.4202 - mape: 3.2384 - rmse: 2.0427 - ar: 1.1692 - val_loss: 3.3406 - val_mse: 3.3406 - val_mae: 1.3489 - val_mape: 1.3332 - val_rmse: 1.8277 - val_ar: 0.2857
# Epoch 18/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.0038 - mse: 5.0038 - mae: 1.5243 - mape: 3.1195 - rmse: 2.2221 - ar: 1.2732 - val_loss: 3.2211 - val_mse: 3.2211 - val_mae: 1.3106 - val_mape: 1.2585 - val_rmse: 1.7948 - val_ar: 0.3544
# Epoch 19/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.4652 - mse: 4.4652 - mae: 1.4226 - mape: 1.9509 - rmse: 2.0878 - ar: 1.2488 - val_loss: 3.2738 - val_mse: 3.2738 - val_mae: 1.3358 - val_mape: 1.1472 - val_rmse: 1.8094 - val_ar: 0.2863
# [MSE Baseline] train: 6.6616795451245086  test: 4.04776621043118
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2738 - mse: 3.2738 - mae: 1.3358 - mape: 1.1472 - rmse: 1.8094 - ar: 0.2863

# %% [markdown]
# ## Results

# %%
df = pd.DataFrame(data = results, index = data_names, columns = metrics)
df.loc['mean'] = results.mean(axis=0)
df
# Out:
#           loss       mse       mae       mape      rmse        ar
# GOOG  6.464830  6.464830  1.655887   1.518776  2.542603  0.337193
# AAPL  0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# AMZN  7.193920  7.193920  1.497680  10.653612  2.682148  0.711778
# FB    8.719451  8.719451  1.687678   2.152505  2.952872  0.583179
# TSLA  3.273782  3.273782  1.335839   1.147166  1.809360  0.286283
# mean  5.130397  5.130397  1.235417   3.094412  1.997397  0.383687
