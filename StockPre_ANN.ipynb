# %% [markdown]
# # Imports

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# general array and data handling
import numpy as np
import pandas as pd

# tensor operations and neural networks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LeakyReLU, Flatten

# Ploting
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data Loading

# %%
#for use in google colaboratory
#!git clone https://github.com/shusunny/GAN-stock-entry.git

# %%
data_names = ["GOOG","AAPL","AMZN","FB","TSLA"]
data_name = data_names[0]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path)
# Out:
# GAN-stock-entry/datasets/GOOG.csv

# %%
dataframe.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   1089.420897  1100.046811  1079.321435  1090.083688  1090.083688
# std     268.589405   272.693779   265.381490   269.099996   269.099996
# min     667.849976   672.299988   663.059998   668.260010   668.260010
# 25%     835.755005   841.975006   831.254975   836.994995   836.994995
# 50%    1083.560059  1094.244995  1072.204956  1082.760010  1082.760010
# 75%    1229.390015  1241.369995  1219.445007  1230.540039  1230.540039
# max    1824.520020  1847.199951  1822.650024  1827.989990  1827.989990
#
#              Volume
# count  1.259000e+03
# mean   1.671534e+06
# std    7.686312e+05
# min    3.468000e+05
# 25%    1.209400e+06
# 50%    1.466700e+06
# 75%    1.889050e+06
# max    6.348100e+06

# %%
dataframe.shape
# Out:
# (1259, 7)

# %%
def add_Entry(dataframe):
  for i in range(0,dataframe.shape[0]):
    dataframe.loc[dataframe.index[i],'Entry'] = np.round((dataframe.iloc[i,3]+ (dataframe.iloc[i,2] -dataframe.iloc[i,3])*0.2),5)
  return dataframe

dataframe=add_Entry(dataframe)
dataframe.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-01-04  743.000000  744.059998  731.257996  741.840027  741.840027
# 1  2016-01-05  746.450012  752.000000  738.640015  742.580017  742.580017
# 2  2016-01-06  730.000000  747.179993  728.919983  743.619995  743.619995
# 3  2016-01-07  730.309998  738.500000  719.059998  726.390015  726.390015
# 4  2016-01-08  731.450012  733.229980  713.000000  714.469971  714.469971
#
#     Volume      Entry
# 0  3272800  733.81840
# 1  1950700  741.31201
# 2  1947000  732.57198
# 3  2963700  722.94800
# 4  2450900  717.04600

# %%
ax = plt.gca()
dataframe.iloc[0:100].plot(x='Date',y='Open',ax=ax)
dataframe.iloc[0:100].plot(x='Date',y='Entry', ax=ax)

plt.title("First 100 days Open and Entry price")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# # Preprocessing

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    # shape : (n_batch, n_sequence, n_features)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    std[std==0] = 1
    samples = (samples - mean[:,None,:])/std[:,None,:] #standarize along each feature
    targets = (targets - mean[:,6:7])/std[:,6:7] # The entry value is our target
    return samples, targets

# %%
# TimeseriesGenerator Check

data = np.array([[i, i**2,i**3,i**4] for i in range(11)])
targets = np.array([[i**4] for i in range(11)])

print(targets.shape)

mean = data[:-1].mean(axis=0)[None,:]
std = data[:-1].std(axis=0)[None,:]

data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=10, sampling_rate=1,
                               batch_size=2)
batch_0 = data_gen[0]
x, y = batch_0

print(np.array(x*std+mean,dtype = np.int))
print(y*std[..., 3]+mean[..., 3])
# Out:
# (11, 1)
# [[[   0    0    0    0]
#   [   1    1    1    1]
#   [   2    4    8   16]
#   [   3    9   27   81]
#   [   4   16   64  256]
#   [   5   25  125  625]
#   [   6   36  216 1296]
#   [   7   49  343 2401]
#   [   8   64  512 4096]
#   [   9   81  729 6561]]]
# []

# %%
data.shape
# Out:
# (11, 4)

# %%
n_sequence = 5
n_batch = 128
n_features = 7

def get_gen_train_test(dataframe):
  data = dataframe.drop(columns='Date').to_numpy()
  targets = data[:,3, None] #add none to have same number of dimensions as data
  #targets = data
  n_samples = data.shape[0]

  train_test_split=int(n_samples*0.9)

  data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
  data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)
  
  return data_gen_train, data_gen_test

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

# %%
data_gen_train[0]
# Out:
# (array([[[ 1.81315331e+00,  1.89677802e+00,  1.15129681e+00, ...,
#            1.30112422e+00,  1.81173145e+00,  1.38149536e+00],
#          [-6.57688733e-01, -7.52972334e-01, -9.75300566e-01, ...,
#           -8.43508975e-01,  1.15751418e-01, -9.57634754e-01],
#          [-2.66239350e-01, -7.63868799e-01, -8.21767497e-01, ...,
#           -1.26815614e+00, -8.86719578e-02, -8.39121916e-01],
#          [-1.08245134e+00, -4.89630134e-01, -6.36148363e-01, ...,
#           -1.68689524e-01, -8.65761888e-01, -6.24252654e-01],
#          [ 1.93226113e-01,  1.09693250e-01,  1.28191961e+00, ...,
#            9.79230424e-01, -9.73049022e-01,  1.03951397e+00]],
#
#         [[-1.68891637e+00, -1.64234577e+00, -1.56817895e+00, ...,
#           -1.47737178e+00, -7.34963560e-01, -1.59004562e+00],
#          [-2.60434529e-01, -4.15602305e-01, -3.05800114e-01, ...,
#           -1.56874978e-01, -1.14382210e+00, -3.29812456e-01],
#          [ 5.03886078e-01,  1.95288809e-01,  2.66132372e-01, ...,
#           -5.31495012e-01,  9.35535676e-01,  2.52561761e-01],
#          [ 9.77724552e-02,  5.08785191e-01,  6.77545030e-02, ...,
#            7.95592943e-01,  1.42855035e+00,  1.59388303e-01],
#          [ 1.34769237e+00,  1.35387407e+00,  1.54009219e+00, ...,
#            1.37014882e+00, -4.85300366e-01,  1.50790802e+00]],
#
#         [[-1.81450083e+00, -1.70753800e+00, -1.88854984e+00, ...,
#           -1.85344890e+00,  1.82187495e+00, -1.89258824e+00],
#          [ 1.95066262e-01, -2.53716578e-01,  2.31730420e-01, ...,
#           -2.56718865e-01, -1.15748091e-01,  1.54583054e-01],
#          [-3.93428309e-02,  7.20412030e-02,  1.62488714e-01, ...,
#            7.99922536e-01, -1.25007938e+00,  1.50286784e-01],
#          [ 4.47147415e-01,  1.28386201e+00,  4.03097204e-01, ...,
#            6.38163215e-01, -2.46543433e-01,  5.58059630e-01],
#          [ 1.21162998e+00,  6.05351366e-01,  1.09123351e+00, ...,
#            6.72082016e-01, -2.09504044e-01,  1.02965877e+00]],
#
#         ...,
#
#         [[ 9.26948908e-01,  2.43217006e-01,  4.02654463e-01, ...,
#            1.02945495e+00,  6.71535461e-02,  3.80578101e-01],
#          [ 6.08825945e-01,  1.66049939e+00,  1.75155386e+00, ...,
#            1.26747695e+00, -1.62062974e+00,  1.74516390e+00],
#          [-5.33863678e-01, -1.39913628e+00, -1.07619075e+00, ...,
#         [  0.15823581],
#         [  1.03300654],
#         [  0.59088734],
#         [  2.25032556],
#         [ -3.07179247],
#         [  1.88410958],
#         [  9.11550461],
#         [  4.13962082],
#         [  1.62238859],
#         [  1.01946863],
#         [  0.55122609],
#         [  2.27644917],
#         [  0.68264043],
#         [ -4.37109476],
#         [  0.71252957],
#         [ -0.63915864],
#         [  4.02375683],
#         [  4.38000299],
#         [ -1.27995696],
#         [  1.00423628],
#         [  7.31461708],
#         [  1.25164413],
#         [  1.28646173],
#         [  2.45129902],
#         [ -1.40817414],
#         [  2.05398928],
#         [  2.18553747],
#         [  2.11853165],
#         [  2.124949  ],
#         [ -0.85589764],
#         [ -1.68533298],
#         [  6.14836117],
#         [  0.09434172],
#         [  3.22974606],
#         [ -0.7031128 ],
#         [ -1.16197062],
#         [  2.19430496],
#         [  2.79422321],
#         [ -2.62394968],
#         [ -1.9152474 ],
#         [  0.84647269],
#         [  0.73212922],
#         [ 14.58511769],
#         [  1.33072096],
#         [  0.37175517],
#         [  1.5066685 ],
#         [  0.13331921],
#         [  0.7805593 ],
#         [ -0.49143723],
#         [  0.09924307],
#         [  1.88193747],
#         [  0.45845767],
#         [  0.81236219],
#         [  5.0094631 ],
#         [  3.28034471],
#         [ -0.94293735],
#         [  0.18836372],
#         [  1.73981618],
#         [  0.18170982],
#         [  1.23178317],
#         [  5.75670454],
#         [ -1.30278736],
#         [  1.63888029],
#         [  2.28070899],
#         [  0.20633967],
#         [  0.68076231],
#         [  2.66518333],
#         [ -1.27995696],
#         [ -0.7768122 ],
#         [ -1.58911963],
#         [ -1.14481158],
#         [  5.10840957],
#         [ -4.05170657],
#         [  1.80829783],
#         [ -1.14481158]]))

# %%
# test on data

x_gen, y_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=1)[0]
print(x_gen)
print(y_gen)

x = data[None, :5,:]
mean = x.mean(axis=1)
std = x.std(axis=1)
x = (x - mean)/std
y = (data[5,3] - mean[...,3])/std[...,3]
print(x)
print(y)

assert (x_gen == x).all()
assert (y_gen == y).all()
# Out:
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# []
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [5.69853465]

# %%
y_gen.shape
# Out:
# (1, 0)

# %% [markdown]
# # Baseline

# %%
# baseline: use previous day as estimation for the next
squared_error = 0
def mean_squared_error(X, lenght = 5):
  squared_error = 0
  for i in range(0, X.shape[0] - lenght):
    x = X[i:i+lenght]
    mean = x.mean()
    std = x.std()
    x = (x - mean)/std
    y = (X[i+lenght] - mean)/std
    squared_error += np.square(x[-1]-y)
  return squared_error/X.shape[0]

baseline_error = mean_squared_error(data[:,3])
baseline_error
# Out:
# 3.4528189810500125

# %%
data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=32)

# baseline: use previous day as estimation for the next
def mean_squared_error(dataset):
  mse=0
  for X_batch, y_batch in dataset:
    # X_batch.shape : (n_batch, n_sequence, n_features)
    #mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
    mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
  mse /= len(dataset)
  return mse

baseline_error = mean_squared_error(data_gen)
baseline_error
# Out:
# C:\Users\shusu\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\shusu\Anaconda3\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %% [markdown]
# # Utilities

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
def mse(y_true, y_pred):
  return tf.reduce_mean(tf.square(y_true-y_pred))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true-y_pred)))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:] > y_true[:-1],tf.float32)
    return tf.reduce_mean((y_true[1:]-y_true[:-1])*mask)

# %% [markdown]
# # ANN

# %%
def make_ANN_model():

  inputs = Input(shape=(n_sequence, n_features,))
  inputs_flatten = Flatten()(inputs)
  ann_1 = Dense(units=1000, activation=None)(inputs_flatten)
  batch_norm1=tf.keras.layers.BatchNormalization()(ann_1)
  ann_1_LRelu = LeakyReLU(alpha=0.3)(ann_1) 
  ann_1_droput = Dropout(0.3)(ann_1_LRelu)
  ann_2 = Dense(units=100, activation=None)(ann_1_droput)
  batch_norm2=tf.keras.layers.BatchNormalization()(ann_2)
  ann_2_LRelu = LeakyReLU(alpha=0.3)(ann_2) 
  ann_2_droput = Dropout(0.3)(ann_2_LRelu)
  output_dense = Dense(1, activation=None)(ann_2_droput)
  output = LeakyReLU(alpha=0.3)(output_dense) 


  model = Model(inputs = inputs, outputs = output)
  #model.compile(loss=generator_loss)
  model.compile(loss='mse', metrics = [mse , mae, mape, rmse, ar])
  #model.compile(loss=None, metrics = [mse , mae, mape, rmse])
  model.summary()

  #return model, slice_model
  return model

# %% [markdown]
# # Visualization

# %%
metrics = ["loss", 'mse','mae','mape','rmse','ar']
def plot_history(history):
  #metrics = ["loss", 'mse','mae','mape','rmse','ar']
  #metrics = ["gen_loss","gen_slice_loss", 'mse','mae','mape','rmae','ar']
  for metric_name in metrics:  
    plt.figure()
    plt.title(metric_name)
    plt.xlabel('Iterations')
    plt.ylabel(metric_name)
    plt.plot(history.history[metric_name], label='train')
    plt.plot(history.history["val_"+metric_name], label='test')
    plt.legend()
  plt.show()

#plot_history(history)

# %%
def plot_frame(sequence, target, model):
  sequence, target = data_gen_test[0]
  y_pred = model.predict(sequence)
  y_true = target

  plt.figure()
  plt.title("Entry price errors")
  plt.xlabel('Test samples')
  plt.ylabel("Errors")
  plt.plot(y_true, label="true")
  plt.plot(y_pred, label="prediction")
  plt.legend()
  plt.show()

#plot_frame(*data_gen_test[0], lstm)

# %% [markdown]
# # Test on all datasets

# %%
results = np.zeros((5,6))

# %% [markdown]
# ### Google Stock

# %%
data_name = data_names[0]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 
100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.4575 - mse: 4.4575 - mae: 1.4011 - mape: 2.2554 - rmse: 2.1002 - ar: 1.1965 - val_loss: 3.7709 - val_mse: 3.7709 - val_mae: 1.4274 - val_mape: 3.2950 - val_rmse: 1.9419 - val_ar: 0.5508
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.7043 - mse: 4.7043 - mae: 1.4223 - mape: 1.7600 - rmse: 2.1605 - ar: 1.2374 - val_loss: 3.8109 - val_mse: 3.8109 - val_mae: 1.4353 - val_mape: 2.8320 - val_rmse: 1.9522 - val_ar: 0.4717
# Epoch 14/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.2793 - mse: 5.2793 - mae: 1.4428 - mape: 2.0089 - rmse: 2.2510 - ar: 1.2310 - val_loss: 3.8275 - val_mse: 3.8275 - val_mae: 1.4384 - val_mape: 3.1243 - val_rmse: 1.9564 - val_ar: 0.5616
# Epoch 15/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.5069 - mse: 5.5069 - mae: 1.4675 - mape: 1.9933 - rmse: 2.3116 - ar: 1.1967 - val_loss: 3.8932 - val_mse: 3.8932 - val_mae: 1.4776 - val_mape: 4.4131 - val_rmse: 1.9731 - val_ar: 0.5695
# Epoch 16/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.0295 - mse: 5.0295 - mae: 1.4391 - mape: 1.9297 - rmse: 2.2021 - ar: 1.2258 - val_loss: 4.3465 - val_mse: 4.3465 - val_mae: 1.5600 - val_mape: 3.4565 - val_rmse: 2.0848 - val_ar: 0.4863
# [MSE Baseline] train: 6.395901603878914  test: 5.120497475636998
# 1/1 [==============================] - 0s 970us/step - loss: 4.3465 - mse: 4.3465 - mae: 1.5600 - mape: 3.4565 - rmse: 2.0848 - ar: 0.4863

# %% [markdown]
# ### Apple Stock

# %%
data_name = data_names[1]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100,
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[1] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/AAPL.csv
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 20ms/step - loss: 5.1293 - mse: 5.1293 - mae: 1.5889 - mape: 2.0727 - rmse: 2.2331 - ar: 1.0465 - val_loss: 6.5442 - val_mse: 6.5442 - val_mae: 1.6438 - val_mape: 1.3634 - val_rmse: 2.5582 - val_ar: 0.4334
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.6409 - mse: 5.6409 - mae: 1.5472 - mape: 1.7276 - rmse: 2.3596 - ar: 1.1989 - val_loss: 6.4650 - val_mse: 6.4650 - val_mae: 1.6832 - val_mape: 1.6317 - val_rmse: 2.5426 - val_ar: 0.2644
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8722 - mse: 4.8722 - mae: 1.4327 - mape: 4.0399 - rmse: 2.1854 - ar: 1.0470 - val_loss: 6.6996 - val_mse: 6.6996 - val_mae: 1.6425 - val_mape: 1.3843 - val_rmse: 2.5884 - val_ar: 0.2734
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8093 - mse: 4.8093 - mae: 1.4497 - mape: 5.4811 - rmse: 2.1642 - ar: 1.0853 - val_loss: 6.7774 - val_mse: 6.7774 - val_mae: 1.6925 - val_mape: 1.4092 - val_rmse: 2.6033 - val_ar: 0.3254
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6149 - mse: 4.6149 - mae: 1.3597 - mape: 1.5067 - rmse: 2.1312 - ar: 1.0677 - val_loss: 6.4678 - val_mse: 6.4678 - val_mae: 1.6045 - val_mape: 1.3445 - val_rmse: 2.5432 - val_ar: 0.4476
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9573 - mse: 4.9573 - mae: 1.5173 - mape: 2.9602 - rmse: 2.2183 - ar: 1.2506 - val_loss: 6.3923 - val_mse: 6.3923 - val_mae: 1.6340 - val_mape: 1.4114 - val_rmse: 2.5283 - val_ar: 0.2903
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.7987 - mse: 4.7987 - mae: 1.4344 - mape: 5.9929 - rmse: 2.1565 - ar: 1.1056 - val_loss: 6.4898 - val_mse: 6.4898 - val_mae: 1.6653 - val_mape: 1.6337 - val_rmse: 2.5475 - val_ar: 0.3388
# Epoch 8/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.4602 - mse: 5.4602 - mae: 1.4878 - mape: 4.2189 - rmse: 2.3121 - ar: 1.3261 - val_loss: 6.7143 - val_mse: 6.7143 - val_mae: 1.7446 - val_mape: 1.9270 - val_rmse: 2.5912 - val_ar: 0.2094
# Epoch 9/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6515 - mse: 4.6515 - mae: 1.4303 - mape: 3.1821 - rmse: 2.1418 - ar: 1.1436 - val_loss: 6.4253 - val_mse: 6.4253 - val_mae: 1.6625 - val_mape: 1.5894 - val_rmse: 2.5348 - val_ar: 0.4158
# Epoch 10/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9057 - mse: 4.9057 - mae: 1.4626 - mape: 2.1802 - rmse: 2.1891 - ar: 1.2346 - val_loss: 6.3819 - val_mse: 6.3819 - val_mae: 1.6566 - val_mape: 1.6247 - val_rmse: 2.5262 - val_ar: 0.4295
# Epoch 11/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.2052 - mse: 5.2052 - mae: 1.4404 - mape: 5.1604 - rmse: 2.2627 - ar: 1.0984 - val_loss: 6.4359 - val_mse: 6.4359 - val_mae: 1.6544 - val_mape: 1.7881 - val_rmse: 2.5369 - val_ar: 0.4210
# Epoch 12/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.5750 - mse: 4.5750 - mae: 1.4434 - mape: 5.7826 - rmse: 2.1250 - ar: 1.1928 - val_loss: 6.4422 - val_mse: 6.4422 - val_mae: 1.6613 - val_mape: 1.5512 - val_rmse: 2.5382 - val_ar: 0.3561
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.5317 - mse: 4.5317 - mae: 1.3916 - mape: 7.0223 - rmse: 2.1060 - ar: 1.1568 - val_loss: 6.5674 - val_mse: 6.5674 - val_mae: 1.6888 - val_mape: 1.6224 - val_rmse: 2.5627 - val_ar: 0.3851
# Epoch 14/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.7782 - mse: 4.7782 - mae: 1.4330 - mape: 2.7410 - rmse: 2.1639 - ar: 1.2301 - val_loss: 6.4873 - val_mse: 6.4873 - val_mae: 1.6671 - val_mape: 1.5707 - val_rmse: 2.5470 - val_ar: 0.3878
# Epoch 15/100
# 9/9 [==============================] - 0s 5ms/step - loss: 3.7392 - mse: 3.7392 - mae: 1.3372 - mape: 1.8666 - rmse: 1.9309 - ar: 1.1885 - val_loss: 6.4628 - val_mse: 6.4628 - val_mae: 1.6359 - val_mape: 1.3894 - val_rmse: 2.5422 - val_ar: 0.3892
# [MSE Baseline] train: 6.804088743791173  test: 7.507943742017371
# 1/1 [==============================] - 0s 0s/step - loss: 6.4628 - mse: 6.4628 - mae: 1.6359 - mape: 1.3894 - rmse: 2.5422 - ar: 0.3892

# %% [markdown]
# ### Amazon Stock

# %%
data_name = data_names[2]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[2] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/AMZN.csv
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 100)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s

data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[3] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/FB.csv
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 1000)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 100)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 20ms/step - loss: 6.0250 - mse: 6.0250 - mae: 1.6496 - mape: 2.1777 - rmse: 2.4351 - ar: 1.1030 - val_loss: 8.4855 - val_mse: 8.4855 - val_mae: 1.6977 - val_mape: 2.3972 - val_rmse: 2.9130 - val_ar: 0.7708
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4536 - mse: 6.4536 - mae: 1.5282 - mape: 2.6050 - rmse: 2.5078 - ar: 1.1800 - val_loss: 7.8061 - val_mse: 7.8061 - val_mae: 1.6881 - val_mape: 3.7494 - val_rmse: 2.7939 - val_ar: 0.7221
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.9165 - mse: 5.9165 - mae: 1.4939 - mape: 2.4253 - rmse: 2.3738 - ar: 1.1541 - val_loss: 8.0995 - val_mse: 8.0995 - val_mae: 1.7152 - val_mape: 1.9517 - val_rmse: 2.8460 - val_ar: 0.6545
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9470 - mse: 4.9470 - mae: 1.4379 - mape: 2.6632 - rmse: 2.1995 - ar: 1.2296 - val_loss: 7.9682 - val_mse: 7.9682 - val_mae: 1.6369 - val_mape: 1.6968 - val_rmse: 2.8228 - val_ar: 0.6645
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.8090 - mse: 5.8090 - mae: 1.5244 - mape: 1.5764 - rmse: 2.3899 - ar: 1.2048 - val_loss: 7.8124 - val_mse: 7.8124 - val_mae: 1.6665 - val_mape: 2.7257 - val_rmse: 2.7951 - val_ar: 0.6032
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6154 - mse: 4.6154 - mae: 1.4282 - mape: 2.9110 - rmse: 2.1339 - ar: 1.1542 - val_loss: 8.0930 - val_mse: 8.0930 - val_mae: 1.6640 - val_mape: 1.6362 - val_rmse: 2.8448 - val_ar: 0.6717
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9390 - mse: 4.9390 - mae: 1.4153 - mape: 2.2494 - rmse: 2.1837 - ar: 1.2088 - val_loss: 8.1075 - val_mse: 8.1075 - val_mae: 1.6831 - val_mape: 2.6471 - val_rmse: 2.8474 - val_ar: 0.5541
# [MSE Baseline] train: 5.222938991411206  test: 9.572238032577555
# 1/1 [==============================] - 0s 998us/step - loss: 8.1075 - mse: 8.1075 - mae: 1.6831 - mape: 2.6471 - rmse: 2.8474 - ar: 0.5541

# %% [markdown]
# ### Tesla Stock

# %%
data_name = data_names[4]
data_path="GAN-stock-entry/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Entry(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[4] = ann.evaluate(data_gen_test)
# Out:
# GAN-stock-entry/datasets/TSLA.csv
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1000)              36000
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1000)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               100100
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 100)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 101
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 136,201
# Trainable params: 136,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 0s 20ms/step - loss: 7.0414 - mse: 7.0414 - mae: 1.7545 - mape: 2.7389 - rmse: 2.6029 - ar: 1.0813 - val_loss: 3.2118 - val_mse: 3.2118 - val_mae: 1.2805 - val_mape: 1.1513 - val_rmse: 1.7921 - val_ar: 0.3357
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.1900 - mse: 5.1900 - mae: 1.5198 - mape: 2.8781 - rmse: 2.2637 - ar: 1.2282 - val_loss: 3.5102 - val_mse: 3.5102 - val_mae: 1.4152 - val_mape: 1.4063 - val_rmse: 1.8735 - val_ar: 0.2715
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.1182 - mse: 5.1182 - mae: 1.4838 - mape: 1.7948 - rmse: 2.2460 - ar: 1.1293 - val_loss: 3.3575 - val_mse: 3.3575 - val_mae: 1.3337 - val_mape: 1.1660 - val_rmse: 1.8324 - val_ar: 0.3191
# Epoch 4/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.6458 - mse: 4.6458 - mae: 1.4233 - mape: 2.4616 - rmse: 2.1330 - ar: 1.2061 - val_loss: 3.2064 - val_mse: 3.2064 - val_mae: 1.2867 - val_mape: 1.0995 - val_rmse: 1.7906 - val_ar: 0.3032
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8510 - mse: 4.8510 - mae: 1.4653 - mape: 3.2048 - rmse: 2.1827 - ar: 1.2577 - val_loss: 3.1920 - val_mse: 3.1920 - val_mae: 1.2772 - val_mape: 1.1947 - val_rmse: 1.7866 - val_ar: 0.3700
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 5.3554 - mse: 5.3554 - mae: 1.5271 - mape: 4.4357 - rmse: 2.2906 - ar: 1.1329 - val_loss: 3.3697 - val_mse: 3.3697 - val_mae: 1.3562 - val_mape: 1.2103 - val_rmse: 1.8357 - val_ar: 0.3028
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.5176 - mse: 4.5176 - mae: 1.4339 - mape: 1.6998 - rmse: 2.1118 - ar: 1.1753 - val_loss: 3.2938 - val_mse: 3.2938 - val_mae: 1.3118 - val_mape: 1.2114 - val_rmse: 1.8149 - val_ar: 0.3218
# Epoch 8/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.2263 - mse: 4.2263 - mae: 1.3796 - mape: 2.1868 - rmse: 2.0512 - ar: 1.1976 - val_loss: 3.3930 - val_mse: 3.3930 - val_mae: 1.3616 - val_mape: 1.3069 - val_rmse: 1.8420 - val_ar: 0.4106
# Epoch 9/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.3176 - mse: 4.3176 - mae: 1.4594 - mape: 1.9857 - rmse: 2.0750 - ar: 1.2117 - val_loss: 3.3252 - val_mse: 3.3252 - val_mae: 1.3296 - val_mape: 1.1488 - val_rmse: 1.8235 - val_ar: 0.2840
# Epoch 10/100
# 9/9 [==============================] - 0s 5ms/step - loss: 4.2098 - mse: 4.2098 - mae: 1.3895 - mape: 3.9044 - rmse: 2.0314 - ar: 1.2008 - val_loss: 3.4003 - val_mse: 3.4003 - val_mae: 1.3552 - val_mape: 1.3749 - val_rmse: 1.8440 - val_ar: 0.3978
# [MSE Baseline] train: 5.209465189166908  test: 4.04776621043118
# 1/1 [==============================] - 0s 0s/step - loss: 3.4003 - mse: 3.4003 - mae: 1.3552 - mape: 1.3749 - rmse: 1.8440 - ar: 0.3978

# %% [markdown]
# ## Results

# %%
df = pd.DataFrame(data = results, index = data_names, columns = metrics)
df.loc['mean'] = results.mean(axis=0)
df
# Out:
#           loss       mse       mae      mape      rmse        ar
# GOOG  4.346518  4.346518  1.560014  3.456533  2.084830  0.486347
# AAPL  6.462795  6.462795  1.635925  1.389356  2.542203  0.389190
# AMZN  7.612556  7.612556  1.512317  7.304441  2.759086  0.634519
# FB    8.107532  8.107532  1.683092  2.647147  2.847373  0.554126
# TSLA  3.400306  3.400306  1.355190  1.374935  1.843992  0.397834
# mean  5.985941  5.985941  1.549308  3.234482  2.415497  0.492403
